# %% [markdown]
# <a href="https://colab.research.google.com/github/sreenidhi2211/Start_DataAnalytics/blob/main/PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %% [markdown]
# here we installed pandas->used to analyse datasets

# %% [markdown]
# then we imported it

# %%
import pandas as pd

# %%
loan = pd.read_csv("/content/Loan payments data.csv")

# %% [markdown]
# then we created a variable called loan to read data from the data set ehich is in csv format

# %%
print(loan)
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# ...

# %% [markdown]
# displayed data using print

# %% [markdown]
# <dataset>.head(n)->1st n rows "but by ddefault if n value is not given it takes n=5
# <dataset>.tail(n)->last n rows
# <dataset>.info()->info about dataset
# <dataset>.describe()->statastical summary

# %%
print(type(loan))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# to know the type of data used here

# %%
loan.head(15)
# Out:
#         Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0   xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1   xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2   xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3   xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
# 4   xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 5   xqd20160706     PAIDOFF        300      7       9/9/2016  9/15/2016
# 6   xqd20160007     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 7   xqd20160008     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 8   xqd20160909     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 9   xqd20160010     PAIDOFF        800     15      9/10/2016  9/24/2016
# 10  xqd20160011     PAIDOFF        300      7      9/10/2016  9/16/2016
# 11  xqd20160012     PAIDOFF       1000     15      9/10/2016  10/9/2016
# ...

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Loan_ID         500 non-null    object
#  1   loan_status     500 non-null    object
#  2   Principal       500 non-null    int64
#  3   terms           500 non-null    int64
#  4   effective_date  500 non-null    object
#  5   due_date        500 non-null    object
#  6   paid_off_time   400 non-null    object
#  7   past_due_days   200 non-null    float64
#  8   age             500 non-null    int64
#  9   education       500 non-null    object
#  10  Gender          500 non-null    object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 43.1+ KB

# %%
loan.describe()
# Out:
#          Principal       terms  past_due_days         age
# count   500.000000  500.000000      200.00000  500.000000
# mean    943.200000   22.824000       36.01000   31.116000
# std     115.240274    8.000064       29.38088    6.084784
# min     300.000000    7.000000        1.00000   18.000000
# 25%    1000.000000   15.000000        3.00000   27.000000
# 50%    1000.000000   30.000000       37.00000   30.000000
# 75%    1000.000000   30.000000       60.00000   35.000000
# max    1000.000000   30.000000       76.00000   51.000000

# %% [markdown]
# <dataSet>.columns->name of columns
# <dataset>.shape->shape of dataset
# <dataset>.dtypes->datatype of columns
# <dataset>.index->index of information

# %%
loan.columns
# Out:
# Index(['Loan_ID', 'loan_status', 'Principal', 'terms', 'effective_date',
#        'due_date', 'paid_off_time', 'past_due_days', 'age', 'education',
#        'Gender'],
#       dtype='object')

# %%
loan.index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
loan.dtypes
# Out:
# Loan_ID            object
# loan_status        object
# Principal           int64
# terms               int64
# effective_date     object
# due_date           object
# paid_off_time      object
# past_due_days     float64
# age                 int64
# education          object
# Gender             object
# dtype: object

# %%
loan.shape
# Out:
# (500, 11)

# %% [markdown]
#  single colum-><dataset>.['<column name>']SPECIFIED SELECTION columns datatyoe->print(type(<dataset>['<column>'])

# %%
loan['education']
# Out:
# 0      High School or Below
# 1                  Bechalor
# 2                  Bechalor
# 3                   college
# 4                   college
#                ...
# 495    High School or Below
# 496    High School or Below
# 497                 college
# 498                 college
# 499    High School or Below
# Name: education, Length: 500, dtype: object

# %%
print(type(loan['education']))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# DATAFRAME->DATASET
# SERIES->A COLUMN

# %%
loan[['Gender','education']]
# Out:
#      Gender             education
# 0      male  High School or Below
# 1    female              Bechalor
# 2    female              Bechalor
# 3      male               college
# 4    female               college
# ..      ...                   ...
# 495    male  High School or Below
# 496    male  High School or Below
# 497    male               college
# 498  female               college
# 499    male  High School or Below
#
# [500 rows x 2 columns]

# %% [markdown]
# COMMANDS ON SINGLE COLUMN
# dataset['column'].unique()->unique value in series

# %%
loan['education'].unique()
# Out:
# array(['High School or Below', 'Bechalor', 'college', 'Master or Above'],
#       dtype=object)

# %% [markdown]
# dataset['column name'].value_counts()->no of unique values

# %%
loan['education'].value_counts()
# Out:
# education
# college                 220
# High School or Below    209
# Bechalor                 67
# Master or Above           4
# Name: count, dtype: int64

# %% [markdown]
# dataset['cloumn'].mean()->mean of int datatype columns
# replace mean with median ->to get median

# %%
loan['age'].mean()
# Out:
# 31.116

# %%
loan['age'].median()
# Out:
# 30.0

# %%
loan['Principal'].mode()
# Out:
# 0    1000
# Name: Principal, dtype: int64

# %% [markdown]
# SELECTING A PART OF SERIES(COLUMNS)->SLICING
# Value in given nth row of sepcified column -> Dataset['column'][n]
# Values in given m to n rows of sepcified
# column->Dataser['column'][m:n]
# INDEXING:fron 0 to n

# %%
loan['education']
# Out:
# 0      High School or Below
# 1                  Bechalor
# 2                  Bechalor
# 3                   college
# 4                   college
#                ...
# 495    High School or Below
# 496    High School or Below
# 497                 college
# 498                 college
# 499    High School or Below
# Name: education, Length: 500, dtype: object

# %%
loan['education'][4]
# Out:
# 'college'

# %%
loan['due_date'][0:10]
# Out:
# 0    10/7/2016
# 1    10/7/2016
# 2    10/7/2016
# 3    9/22/2016
# 4    10/8/2016
# 5    9/15/2016
# 6    10/8/2016
# 7    10/8/2016
# 8    10/8/2016
# 9    9/24/2016
# Name: due_date, dtype: object

# %% [markdown]
# SLCICING DATAFRAME(dataset)
# with GIVEN indexed rows(multiple rows)
# dataset[m:n]->remember that  index here is  of a row

# %%
loan[495:500]
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# 495  10/11/2016  10/14/2016 19:08            3.0   28  High School or Below
# 496   9/26/2016  10/10/2016 20:02           14.0   26  High School or Below
# 497   9/26/2016   9/29/2016 11:49            3.0   30               college
# 498  11/10/2016  11/11/2016 22:40            1.0   38               college
# 499  10/11/2016  10/19/2016 11:58            8.0   28  High School or Below
#
#      Gender
# 495    male
# 496    male
# 497    male
# 498  female
# 499    male

# %% [markdown]
# SLICING DATAFRAME
# IF SINGLE ROW(LOC&ILOC)
# LOC->search for exact value (if m row it shows m th row only not m+1 row)
# dataset.loc[m] OR dataset.loc[m:n]
# ILC->search for the given index row values(if m row  m+1 row)(since index from 0)
# dataset.iloc[m]
# dataset.ilco[m:n]

# %%
loan.loc[321]
# Out:
# Loan_ID                    xqd20160322
# loan_status                 COLLECTION
# Principal                         1000
# terms                               30
# effective_date               9/10/2016
# due_date                     10/9/2016
# paid_off_time                      NaN
# past_due_days                     60.0
# age                                 28
# education         High School or Below
# Gender                            male
# Name: 321, dtype: object

# %%
loan.loc[0:10]
# Out:
#         Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0   xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1   xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2   xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3   xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
# 4   xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 5   xqd20160706     PAIDOFF        300      7       9/9/2016  9/15/2016
# 6   xqd20160007     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 7   xqd20160008     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 8   xqd20160909     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 9   xqd20160010     PAIDOFF        800     15      9/10/2016  9/24/2016
# 10  xqd20160011     PAIDOFF        300      7      9/10/2016  9/16/2016
#
#       paid_off_time  past_due_days  age             education  Gender
# ...

# %%
loan.iloc[5]
# Out:
# Loan_ID               xqd20160706
# loan_status               PAIDOFF
# Principal                     300
# terms                           7
# effective_date           9/9/2016
# due_date                9/15/2016
# paid_off_time      9/9/2016 13:45
# past_due_days                 NaN
# age                            35
# education         Master or Above
# Gender                       male
# Name: 5, dtype: object

# %%
loan.iloc[2:10]
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3  xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 5  xqd20160706     PAIDOFF        300      7       9/9/2016  9/15/2016
# 6  xqd20160007     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 7  xqd20160008     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 8  xqd20160909     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 9  xqd20160010     PAIDOFF        800     15      9/10/2016  9/24/2016
#
#      paid_off_time  past_due_days  age        education  Gender
# 2  9/25/2016 16:58            NaN   33         Bechalor  female
# 3  9/22/2016 20:00            NaN   27          college    male
# 4  9/23/2016 21:36            NaN   28          college  female
# 5   9/9/2016 13:45            NaN   35  Master or Above    male
# ...

# %% [markdown]
# # RENAMING AND RESETTING

# %%
bank = pd.read_csv("/content/BankChurners.csv")

# %%
bank.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %% [markdown]
# ***SETTING NEW INDEX***
# dataset.set_index('name of the column u want to place in palce of index',inplace =True)

# %%
bank.set_index('CLIENTNUM',inplace=True)

# %%
print(bank)
# Out:
#               Attrition_Flag  Customer_Age Gender  Dependent_count  \
# CLIENTNUM
# 768805383  Existing Customer            45      M                3
# 818770008  Existing Customer            49      F                5
# 713982108  Existing Customer            51      M                3
# 769911858  Existing Customer            40      F                4
# 709106358  Existing Customer            40      M                3
# ...                      ...           ...    ...              ...
# 772366833  Existing Customer            50      M                2
# 710638233  Attrited Customer            41      M                2
# 716506083  Attrited Customer            44      F                1
# 717406983  Attrited Customer            30      M                2
# 714337233  Attrited Customer            43      F                2
#
#           Education_Level Marital_Status Income_Category Card_Category  \
# CLIENTNUM
# ...

# %%
bank.head()
# Out:
#               Attrition_Flag  Customer_Age Gender  Dependent_count  \
# CLIENTNUM
# 768805383  Existing Customer            45      M                3
# 818770008  Existing Customer            49      F                5
# 713982108  Existing Customer            51      M                3
# 769911858  Existing Customer            40      F                4
# 709106358  Existing Customer            40      M                3
#
#           Education_Level Marital_Status Income_Category Card_Category  \
# CLIENTNUM
# 768805383     High School        Married     $60K - $80K          Blue
# 818770008        Graduate         Single  Less than $40K          Blue
# 713982108        Graduate        Married    $80K - $120K          Blue
# 769911858     High School        Unknown  Less than $40K          Blue
# 709106358      Uneducated        Married     $60K - $80K          Blue
#
#            Months_on_book  Total_Relationship_Count  ...  Credit_Limit  \
# ...

# %%
bank.loc(709106358)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     512         try:
# --> 513             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     514         except KeyError:
#
# KeyError: 709106358
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-13db52e0cfc9> in <cell line: 1>()
# ----> 1 bank.loc(709106358)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __call__(self, axis)
#     677
#     678         if axis is not None:
# --> 679             axis_int_none = self.obj._get_axis_number(axis)
#     680         else:
#     681             axis_int_none = axis
#
# ...

# %% [markdown]
# # CREATING A NEW COLUMN
# dataset["new column name"]=values(use 1 )
# dataset["new column name"]=dataset["existing column"](withcondition)

# %%
loan["new"]=1

# %%
loan.head()
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0  xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1  xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3  xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
#
#      paid_off_time  past_due_days  age             education  Gender  new
# 0  9/14/2016 19:31            NaN   45  High School or Below    male    1
# 1   10/7/2016 9:00            NaN   50              Bechalor  female    1
# 2  9/25/2016 16:58            NaN   33              Bechalor  female    1
# 3  9/22/2016 20:00            NaN   27               college    male    1
# 4  9/23/2016 21:36            NaN   28               college  female    1

# %%
loan["del"]=loan['age']/4

# %%
loan.head()
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0  xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1  xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3  xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
#
#      paid_off_time  past_due_days  age             education  Gender  new  \
# 0  9/14/2016 19:31            NaN   45  High School or Below    male    1
# 1   10/7/2016 9:00            NaN   50              Bechalor  female    1
# 2  9/25/2016 16:58            NaN   33              Bechalor  female    1
# 3  9/22/2016 20:00            NaN   27               college    male    1
# 4  9/23/2016 21:36            NaN   28               college  female    1
#
#      del
# 0  11.25
# 1  12.50
# 2   8.25
# 3   6.75
# 4   7.00

# %%
loan["new"]=loan["terms"]*2

# %%
loan.head()
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0  xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1  xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3  xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
#
#      paid_off_time  past_due_days  age             education  Gender  new  \
# 0  9/14/2016 19:31            NaN   45  High School or Below    male   60
# 1   10/7/2016 9:00            NaN   50              Bechalor  female   60
# 2  9/25/2016 16:58            NaN   33              Bechalor  female   60
# 3  9/22/2016 20:00            NaN   27               college    male   30
# 4  9/23/2016 21:36            NaN   28               college  female   60
#
#      del
# 0  11.25
# 1  12.50
# 2   8.25
# 3   6.75
# 4   7.00

# %% [markdown]
# ******DELETION**************
# deleting column->dataset.drop(["column names"],axis=1,inplace=True)
# deleting a row->dataset.drop([m:n],axis=0,inplace=True)

# %%
bank.drop(['Gender'], axis=1, inplace=True)

# %%
bank.head()
# Out:
#               Attrition_Flag  Customer_Age  Dependent_count Education_Level  \
# CLIENTNUM
# 768805383  Existing Customer            45                3     High School
# 818770008  Existing Customer            49                5        Graduate
# 713982108  Existing Customer            51                3        Graduate
# 769911858  Existing Customer            40                4     High School
# 709106358  Existing Customer            40                3      Uneducated
#
#           Marital_Status Income_Category Card_Category  Months_on_book  \
# CLIENTNUM
# 768805383        Married     $60K - $80K          Blue              39
# 818770008         Single  Less than $40K          Blue              44
# 713982108        Married    $80K - $120K          Blue              36
# 769911858        Unknown  Less than $40K          Blue              34
# 709106358        Married     $60K - $80K          Blue              21
#
# ...

# %%
loan.drop(['past_due_days'],axis=1,inplace=True)

# %%
loan.head()
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0  xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1  xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3  xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
#
#      paid_off_time  age             education  Gender  new    del
# 0  9/14/2016 19:31   45  High School or Below    male   60  11.25
# 1   10/7/2016 9:00   50              Bechalor  female   60  12.50
# 2  9/25/2016 16:58   33              Bechalor  female   60   8.25
# 3  9/22/2016 20:00   27               college    male   30   6.75
# 4  9/23/2016 21:36   28               college  female   60   7.00

# %%
bank.drop(['Months_Inactive_12_mon'],axis=1,inplace=True)

# %%
bank.head()
# Out:
#               Attrition_Flag  Customer_Age  Dependent_count Education_Level  \
# CLIENTNUM
# 818770008  Existing Customer            49                5        Graduate
# 713982108  Existing Customer            51                3        Graduate
# 709106358  Existing Customer            40                3      Uneducated
# 713061558  Existing Customer            44                2        Graduate
# 810347208  Existing Customer            51                4         Unknown
#
#           Marital_Status Income_Category Card_Category  Months_on_book  \
# CLIENTNUM
# 818770008         Single  Less than $40K          Blue              44
# 713982108        Married    $80K - $120K          Blue              36
# 709106358        Married     $60K - $80K          Blue              21
# 713061558        Married     $40K - $60K          Blue              36
# 810347208        Married         $120K +          Gold              46
#
# ...

# %% [markdown]
# #RENAME COLUMNS
# dataset.rename(columns ={"old column name":"new column name", as many colums names as u want})

# %%
bank.rename(columns={"Contacts_Count_12_mon":"Contact count"},inplace=True)

# %%
bank.head()
# Out:
#               Attrition_Flag  Customer_Age  Dependent_count Education_Level  \
# CLIENTNUM
# 818770008  Existing Customer            49                5        Graduate
# 713982108  Existing Customer            51                3        Graduate
# 709106358  Existing Customer            40                3      Uneducated
# 713061558  Existing Customer            44                2        Graduate
# 810347208  Existing Customer            51                4         Unknown
#
#           Marital_Status Income_Category Card_Category  Months_on_book  \
# CLIENTNUM
# 818770008         Single  Less than $40K          Blue              44
# 713982108        Married    $80K - $120K          Blue              36
# 709106358        Married     $60K - $80K          Blue              21
# 713061558        Married     $40K - $60K          Blue              36
# 810347208        Married         $120K +          Gold              46
#
# ...

# %% [markdown]
# RESET INDEX
# dataset.reset_index(inplace=True)

# %%
bank.reset_index(inplace=True)

# %%
bank.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age  Dependent_count  \
# 0  818770008  Existing Customer            49                5
# 1  713982108  Existing Customer            51                3
# 2  709106358  Existing Customer            40                3
# 3  713061558  Existing Customer            44                2
# 4  810347208  Existing Customer            51                4
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0        Graduate         Single  Less than $40K          Blue
# 1        Graduate        Married    $80K - $120K          Blue
# 2      Uneducated        Married     $60K - $80K          Blue
# 3        Graduate        Married     $40K - $60K          Blue
# 4         Unknown        Married         $120K +          Gold
#
#    Months_on_book  Total_Relationship_Count  ...  Credit_Limit  \
# 0              44                         6  ...        8256.0
# 1              36                         4  ...        3418.0
# ...

# %% [markdown]
# # DATA PREPROCESSING(CLEANING)
# ->finding null values
# dataset.isnull()
# TRUE->null
# FALSE->not null
# dataset.isnull().sum()->no of null values in each column

# %%
bank.isnull()
# Out:
#        CLIENTNUM  Attrition_Flag  Customer_Age  Dependent_count  \
# 0          False           False         False            False
# 1          False           False         False            False
# 2          False           False         False            False
# 3          False           False         False            False
# 4          False           False         False            False
# ...          ...             ...           ...              ...
# 10120      False           False         False            False
# 10121      False           False         False            False
# 10122      False           False         False            False
# 10123      False           False         False            False
# 10124      False           False         False            False
#
#        Education_Level  Marital_Status  Income_Category  Card_Category  \
# 0                False           False            False          False
# ...

# %%
bank.isnull().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# Income_Category                                                                                                                       0
# ...

# %% [markdown]
# ***HANDLING NULL VALUES***
# 1.Imputation->fill/manipulate value
# dataset['column name'].fillna( value(can be codition also ,inplace=True)
# 2.Dropping->dataset.drop(['colunmname'],axis=1,inplace=True)

# %%
bank['new',]
# Out:
#   File "<ipython-input-73-e8a96b3e736f>", line 1
#     bank['new',inplace=True]
#                ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
bank["new"]=0

# %%
bank.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age  Dependent_count  \
# 0  818770008  Existing Customer            49                5
# 1  713982108  Existing Customer            51                3
# 2  709106358  Existing Customer            40                3
# 3  713061558  Existing Customer            44                2
# 4  810347208  Existing Customer            51                4
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0        Graduate         Single  Less than $40K          Blue
# 1        Graduate        Married    $80K - $120K          Blue
# 2      Uneducated        Married     $60K - $80K          Blue
# 3        Graduate        Married     $40K - $60K          Blue
# 4         Unknown        Married         $120K +          Gold
#
#    Months_on_book  Total_Relationship_Count  ...  Total_Revolving_Bal  \
# 0              44                         6  ...                  864
# ...

# %%
bank.isnull()
# Out:
#        CLIENTNUM  Attrition_Flag  Customer_Age  Dependent_count  \
# 0          False           False         False            False
# 1          False           False         False            False
# 2          False           False         False            False
# 3          False           False         False            False
# 4          False           False         False            False
# ...          ...             ...           ...              ...
# 10120      False           False         False            False
# 10121      False           False         False            False
# 10122      False           False         False            False
# 10123      False           False         False            False
# 10124      False           False         False            False
#
#        Education_Level  Marital_Status  Income_Category  Card_Category  \
# 0                False           False            False          False
# ...

# %%
bank.isnull()
# Out:
#        CLIENTNUM  Attrition_Flag  Customer_Age  Dependent_count  \
# 0          False           False         False            False
# 1          False           False         False            False
# 2          False           False         False            False
# 3          False           False         False            False
# 4          False           False         False            False
# ...          ...             ...           ...              ...
# 10120      False           False         False            False
# 10121      False           False         False            False
# 10122      False           False         False            False
# 10123      False           False         False            False
# 10124      False           False         False            False
#
#        Education_Level  Marital_Status  Income_Category  Card_Category  \
# 0                False           False            False          False
# ...

# %%
bank.isnull()
# Out:
#        CLIENTNUM  Attrition_Flag  Customer_Age  Dependent_count  \
# 0          False           False         False            False
# 1          False           False         False            False
# 2          False           False         False            False
# 3          False           False         False            False
# 4          False           False         False            False
# ...          ...             ...           ...              ...
# 10120      False           False         False            False
# 10121      False           False         False            False
# 10122      False           False         False            False
# 10123      False           False         False            False
# 10124      False           False         False            False
#
#        Education_Level  Marital_Status  Income_Category  Card_Category  \
# 0                False           False            False          False
# ...

# %%
bank.drop(['Months_on_book'],axis=1,inplace=True)

# %%
bank.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age  Dependent_count  \
# 0  818770008  Existing Customer            49                5
# 1  713982108  Existing Customer            51                3
# 2  709106358  Existing Customer            40                3
# 3  713061558  Existing Customer            44                2
# 4  810347208  Existing Customer            51                4
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0        Graduate         Single  Less than $40K          Blue
# 1        Graduate        Married    $80K - $120K          Blue
# 2      Uneducated        Married     $60K - $80K          Blue
# 3        Graduate        Married     $40K - $60K          Blue
# 4         Unknown        Married         $120K +          Gold
#
#    Total_Relationship_Count  Contact count  ...  Total_Revolving_Bal  \
# 0                         6              2  ...                  864
# ...

# %%
bank.dropna(inplace=True)#rows

# %% [markdown]
# #REMOVE DUPLICATES
# to print duplicate values i.e to check
# print(dataset.duplicated())
# to remove duplicates
# dataset.drop_duplicates(inplace=true)

# %%
print(loan.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
print(bank.duplicated())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10120    False
# 10121    False
# 10122    False
# 10123    False
# 10124    False
# Length: 10125, dtype: bool

# %%
bank.drop_duplicates()
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age  Dependent_count  \
# 0      818770008  Existing Customer            49                5
# 1      713982108  Existing Customer            51                3
# 2      709106358  Existing Customer            40                3
# 3      713061558  Existing Customer            44                2
# 4      810347208  Existing Customer            51                4
# ...          ...                ...           ...              ...
# 10120  772366833  Existing Customer            50                2
# 10121  710638233  Attrited Customer            41                2
# 10122  716506083  Attrited Customer            44                1
# 10123  717406983  Attrited Customer            30                2
# 10124  714337233  Attrited Customer            43                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0            Graduate         Single  Less than $40K          Blue
# ...
