# %% [markdown]
# <a href="https://colab.research.google.com/github/sreenidhi2211/EDA-_sales-Data/blob/main/sales_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import os

# %%
os.listdir("/content")
# Out:
# ['.config',
#  'Sales_December_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_September_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_April_2019.csv',
#  'Sales_July_2019.csv',
#  'sample_data']

# %%
import os
for x in os.listdir("/content"):
  if "Sales" in x:
    print(x)
# Out:
# Sales_December_2019.csv
# Sales_November_2019.csv
# Sales_October_2019.csv
# Sales_May_2019.csv
# Sales_September_2019.csv
# Sales_February_2019.csv
# Sales_March_2019.csv
# Sales_January_2019.csv
# Sales_August_2019.csv
# Sales_June_2019.csv
# Sales_April_2019.csv
# Sales_July_2019.csv

# %%
sales=pd.DataFrame()
for x in os.listdir("/content"):
  if "Sales" in x:
    d=pd.read_csv(f"/content/{x}")
    sales=pd.concat([sales,d])

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 186850 entries, 0 to 14370
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 10.0+ MB

# %%
sales.shape
# Out:
# (186850, 6)

# %%
sales.isnull()
# Out:
#        Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 0         False    False             False       False       False
# 1         False    False             False       False       False
# 2         False    False             False       False       False
# 3         False    False             False       False       False
# 4         False    False             False       False       False
# ...         ...      ...               ...         ...         ...
# 14366     False    False             False       False       False
# 14367     False    False             False       False       False
# 14368     False    False             False       False       False
# 14369     False    False             False       False       False
# 14370     False    False             False       False       False
#
#        Purchase Address
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...

# %%
sales.dropna(axis=0,inplace=True)

# %%
sales
# Out:
#       Order ID                 Product Quantity Ordered Price Each  \
# 0       295665      Macbook Pro Laptop                1       1700
# 1       295666      LG Washing Machine                1      600.0
# 2       295667    USB-C Charging Cable                1      11.95
# 3       295668        27in FHD Monitor                1     149.99
# 4       295669    USB-C Charging Cable                1      11.95
# ...        ...                     ...              ...        ...
# 14366   236665        Wired Headphones                1      11.99
# 14367   236666            20in Monitor                1     109.99
# 14368   236667  AAA Batteries (4-pack)                1       2.99
# 14369   236668        Wired Headphones                1      11.99
# 14370   236669  AAA Batteries (4-pack)                1       2.99
#
#            Order Date                        Purchase Address
# 0      12/30/19 00:01  136 Church St, New York City, NY 10001
# ...

# %%
sales.to_csv("/content/finalout.csv",index=False)

# %%
sales
# Out:
#       Order ID                 Product Quantity Ordered Price Each  \
# 0       295665      Macbook Pro Laptop                1       1700
# 1       295666      LG Washing Machine                1      600.0
# 2       295667    USB-C Charging Cable                1      11.95
# 3       295668        27in FHD Monitor                1     149.99
# 4       295669    USB-C Charging Cable                1      11.95
# ...        ...                     ...              ...        ...
# 14366   236665        Wired Headphones                1      11.99
# 14367   236666            20in Monitor                1     109.99
# 14368   236667  AAA Batteries (4-pack)                1       2.99
# 14369   236668        Wired Headphones                1      11.99
# 14370   236669  AAA Batteries (4-pack)                1       2.99
#
#            Order Date                        Purchase Address
# 0      12/30/19 00:01  136 Church St, New York City, NY 10001
# ...

# %%
sales=pd.read_csv("/content/finalout.csv")

# %%
sales
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 0        295665      Macbook Pro Laptop                1       1700
# 1        295666      LG Washing Machine                1      600.0
# 2        295667    USB-C Charging Cable                1      11.95
# 3        295668        27in FHD Monitor                1     149.99
# 4        295669    USB-C Charging Cable                1      11.95
# ...         ...                     ...              ...        ...
# 186300   236665        Wired Headphones                1      11.99
# 186301   236666            20in Monitor                1     109.99
# 186302   236667  AAA Batteries (4-pack)                1       2.99
# 186303   236668        Wired Headphones                1      11.99
# 186304   236669  AAA Batteries (4-pack)                1       2.99
#
#             Order Date                        Purchase Address
# 0       12/30/19 00:01  136 Church St, New York City, NY 10001
# ...

# %%
sales.shape
# Out:
# (186305, 6)

# %%
sales['Product'].value_counts()
# Out:
# Product
# USB-C Charging Cable          21903
# Lightning Charging Cable      21658
# AAA Batteries (4-pack)        20641
# AA Batteries (4-pack)         20577
# Wired Headphones              18882
# Apple Airpods Headphones      15549
# Bose SoundSport Headphones    13325
# 27in FHD Monitor               7507
# iPhone                         6842
# 27in 4K Gaming Monitor         6230
# 34in Ultrawide Monitor         6181
# Google Phone                   5525
# Flatscreen TV                  4800
# Macbook Pro Laptop             4724
# ThinkPad Laptop                4128
# 20in Monitor                   4101
# Vareebadd Phone                2065
# LG Washing Machine              666
# LG Dryer                        646
# Product                         355
# Name: count, dtype: int64

# %%
sales=sales[sales['Product']!='Product']

# %%
sales.shape
# Out:
# (185950, 6)

# %%
sales['Product'].value_counts()
# Out:
# Product
# USB-C Charging Cable          21903
# Lightning Charging Cable      21658
# AAA Batteries (4-pack)        20641
# AA Batteries (4-pack)         20577
# Wired Headphones              18882
# Apple Airpods Headphones      15549
# Bose SoundSport Headphones    13325
# 27in FHD Monitor               7507
# iPhone                         6842
# 27in 4K Gaming Monitor         6230
# 34in Ultrawide Monitor         6181
# Google Phone                   5525
# Flatscreen TV                  4800
# Macbook Pro Laptop             4724
# ThinkPad Laptop                4128
# 20in Monitor                   4101
# Vareebadd Phone                2065
# LG Washing Machine              666
# LG Dryer                        646
# Name: count, dtype: int64

# %%
sales.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
sales['Quantity Ordered']=pd.to_numeric(sales['Quantity Ordered'])
# Out:
# <ipython-input-21-651678accd2b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales['Quantity Ordered']=pd.to_numeric(sales['Quantity Ordered'])

# %%
sales.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered     int64
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
sales.head()
# Out:
#   Order ID               Product  Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                 1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                 1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                 1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                 1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                 1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %%
sales['Order Date']=pd.to_datetime(sales['Order Date'])
# Out:
# <ipython-input-24-d3cfd0d9de2b>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sales['Order Date']=pd.to_datetime(sales['Order Date'])
# <ipython-input-24-d3cfd0d9de2b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales['Order Date']=pd.to_datetime(sales['Order Date'])

# %%
sales.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered             int64
# Price Each                  object
# Order Date          datetime64[ns]
# Purchase Address            object
# dtype: object

# %%
sales['Price Each']=pd.to_numeric(sales['Price Each'])
# Out:
# <ipython-input-26-22a3b28638bd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales['Price Each']=pd.to_numeric(sales['Price Each'])

# %%
sales.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered             int64
# Price Each                 float64
# Order Date          datetime64[ns]
# Purchase Address            object
# dtype: object

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185950 entries, 0 to 186304
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  185950 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 9.9+ MB

# %%
sales['Sales']=sales['Quantity Ordered']*sales['Price Each']
# Out:
# <ipython-input-29-db7b9d51a2e8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales['Sales']=sales['Quantity Ordered']*sales['Price Each']

# %%
sales.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#            Order Date                        Purchase Address    Sales
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001  1700.00
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001   600.00
# 2 2019-12-12 18:21:00    277 Main St, New York City, NY 10001    11.95
# 3 2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016   149.99
# 4 2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301    11.95

# %%
sales['Month']=sales['Order Date'].dt.strftime('%m')
# Out:
# <ipython-input-31-720df97899d5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales['Month']=sales['Order Date'].dt.strftime('%m')

# %%
sales.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#            Order Date                        Purchase Address    Sales Month
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001  1700.00    12
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001   600.00    12
# 2 2019-12-12 18:21:00    277 Main St, New York City, NY 10001    11.95    12
# 3 2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016   149.99    12
# 4 2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301    11.95    12

# %%
sales.shape
# Out:
# (185950, 8)

# %% [markdown]
# #BEST MONTH FOR SALES IN 2019

# %%
sales['Month'].value_counts()
# Out:
# Month
# 12    24984
# 10    20282
# 04    18279
# 11    17573
# 05    16566
# 03    15153
# 07    14293
# 06    13554
# 02    11975
# 08    11961
# 09    11621
# 01     9709
# Name: count, dtype: int64

# %%
sales.groupby('Month')['Sales'].sum().sort_values(ascending=False)
# Out:
# Month
# 12    4613443.34
# 10    3736726.88
# 04    3390670.24
# 11    3199603.20
# 05    3152606.75
# 03    2807100.38
# 07    2647775.76
# 06    2577802.26
# 08    2244467.88
# 02    2202022.42
# 09    2097560.13
# 01    1822256.73
# Name: Sales, dtype: float64

# %% [markdown]
# **DECEMBER MONTH HAS THE BEST SALES**

# %% [markdown]
# #CITY THAT SOLD MOST PRODUCTS IN 2019

# %%
sales.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#            Order Date                        Purchase Address    Sales Month
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001  1700.00    12
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001   600.00    12
# 2 2019-12-12 18:21:00    277 Main St, New York City, NY 10001    11.95    12
# 3 2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016   149.99    12
# 4 2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301    11.95    12

# %% [markdown]
# #

# %%
sales['Purchase Address'].value_counts()
# Out:
# Purchase Address
# 193 Forest St, San Francisco, CA 94016      9
# 223 Elm St, Los Angeles, CA 90001           8
# 279 Sunset St, San Francisco, CA 94016      8
# 662 Chestnut St, San Francisco, CA 94016    7
# 640 West St, San Francisco, CA 94016        7
#                                            ..
# 913 Cedar St, San Francisco, CA 94016       1
# 993 Highland St, Boston, MA 02215           1
# 478 4th St, Atlanta, GA 30301               1
# 102 Meadow St, Seattle, WA 98101            1
# 743 9th St, New York City, NY 10001         1
# Name: count, Length: 140787, dtype: int64

# %%
sales['Purchase Address'].str.split(",").str[1]
# Out:
# 0          New York City
# 1          New York City
# 2          New York City
# 3          San Francisco
# 4                Atlanta
#                ...
# 186300           Atlanta
# 186301     San Francisco
# 186302            Dallas
# 186303            Austin
# 186304     New York City
# Name: Purchase Address, Length: 185950, dtype: object

# %%
sales['City']=sales['Purchase Address'].str.split(",").str[1]
# Out:
# <ipython-input-39-f7ce55896fb4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales['City']=sales['Purchase Address'].str.split(",").str[1]

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185950 entries, 0 to 186304
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  185950 non-null  object
#  6   Sales             185950 non-null  float64
#  7   Month             185950 non-null  object
#  8   City              185950 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 14.2+ MB

# %%
sales.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#            Order Date                        Purchase Address    Sales Month  \
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001  1700.00    12
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001   600.00    12
# 2 2019-12-12 18:21:00    277 Main St, New York City, NY 10001    11.95    12
# 3 2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016   149.99    12
# 4 2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301    11.95    12
#
#              City
# 0   New York City
# 1   New York City
# 2   New York City
# 3   San Francisco
# 4         Atlanta

# %%
sales.groupby('City')['Sales'].sum().sort_values(ascending=False)
# Out:
# City
#  San Francisco    8262203.91
#  Los Angeles      5452570.80
#  New York City    4664317.43
#  Boston           3661642.01
#  Atlanta          2795498.58
#  Dallas           2767975.40
#  Seattle          2747755.48
#  Portland         2320490.61
#  Austin           1819581.75
# Name: Sales, dtype: float64

# %% [markdown]
# **SAN FRANCISCO HAS THE MOST PRODUCT SALES IN 2019**

# %% [markdown]
# #BEST TIME FOR SELLING IN 2019

# %%
sales['Hour']=pd.to_datetime(sales['Order Date'])
# Out:
# <ipython-input-43-5b539b146f66>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales['Hour']=pd.to_datetime(sales['Order Date'])

# %%
sales['Hour']=sales['Order Date'].dt.hour
# Out:
# <ipython-input-44-f0d3b26f19b7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales['Hour']=sales['Order Date'].dt.hour

# %%
sales['Hour']
# Out:
# 0          0
# 1          7
# 2         18
# 3         15
# 4         12
#           ..
# 186300    16
# 186301    20
# 186302    22
# 186303    19
# 186304     1
# Name: Hour, Length: 185950, dtype: int32

# %%
sales.groupby('Hour')['Sales'].sum().sort_values(ascending=False)
# Out:
# Hour
# 19    2412938.54
# 12    2316821.34
# 11    2300610.24
# 20    2281716.24
# 18    2219348.30
# 13    2155389.80
# 17    2129361.61
# 14    2083672.73
# 21    2042000.86
# 10    1944286.77
# 15    1941549.60
# 16    1904601.31
# 9     1639030.58
# 22    1607549.21
# 8     1192348.97
# 23    1179304.44
# 7      744854.12
# 0      713721.27
# 1      460866.88
# 6      448113.00
# 2      234851.44
# 5      230679.82
# 4      162661.01
# 3      145757.89
# Name: Sales, dtype: float64

# %% [markdown]
#  **BEST SELLING TIME IN 2019 IS : 19:00**

# %% [markdown]
# #MOST SOLD PRODUCT IN 2019

# %%
sales.groupby('Product')['Quantity Ordered'].sum().sort_values(ascending=False)
# Out:
# Product
# AAA Batteries (4-pack)        31017
# AA Batteries (4-pack)         27635
# USB-C Charging Cable          23975
# Lightning Charging Cable      23217
# Wired Headphones              20557
# Apple Airpods Headphones      15661
# Bose SoundSport Headphones    13457
# 27in FHD Monitor               7550
# iPhone                         6849
# 27in 4K Gaming Monitor         6244
# 34in Ultrawide Monitor         6199
# Google Phone                   5532
# Flatscreen TV                  4819
# Macbook Pro Laptop             4728
# ThinkPad Laptop                4130
# 20in Monitor                   4129
# Vareebadd Phone                2068
# LG Washing Machine              666
# LG Dryer                        646
# Name: Quantity Ordered, dtype: int64

# %% [markdown]
# **MOST SOLD PRODUCT IN 2019 AAA Batteries (4-pack)**
